# %% [markdown]
# 1) What would be good metrics for success for an advertising-driven consumer product, such as Buzzfeed, Youtube or Google Search?
#
# ```
#
# Spend should drive ROI in multiples, but between them there are a few important things. This assumes you have a good strategy, to start.
#
# Are you getting enough eyeballs for your ad spend?
# Spend >>> Ads served>>> Impressions >>> Viewable impressions...plus derived metrics like In-View Rate, view-through rate, etc..
#
# Are you converting enough given your spend?
# Spend>>> Click-throughs >>> Registrations >>> Conversions/Sales
#
# All of these should be segmented by various types of user attributes to create a well-rounded picture of your target universe.
# ```
#
#
# 1b) A service-driven consumer product, such as Uber, Flickr, Venmo?
# ```
# ```
#
# 2) What would be good metrics of success for a productivity tool?
# ```
# Daily active users
# ```
# 2b) A MOOC- Massive open online courses?
# ```
# A good metric of success would probably be something like completion rate, as sign up rates can be very high and completion rates often very low like 2-5%.
# ```
# 3) What would be good metrics of success for an e-commerce product, such as Etsy, Groupon and Birchbox?
# ```
# 1. Number of unique customers placing orders/sales
# 2. Number of repeat customers
# 3. Conversion - no of visits to number of orders
#
# Some other metrics can be:
#
# 1. Amount per order
# 2. Number of items per order
# 3. Profit amount per order
# 4. Frequency of the orders
# 5. Conversion of promotional products vs non-promotional.
# 6. Conversion of social media posts
# ```
# 3b) A subscription product, Neflix, Hulu?
# ```
# Pre product/market fit:
# User feedback (1)
# Development velocity
# Signups
# Activation
# Usage
# NPS - net promoter score
#
# Post product/market fit, pre scale:
# Conversion
# Retention
# Monthly recurring revenue
# Average revenue per account
#
# Post scale:
# Customer lifetime value
# Customer Acquisition cost
#
# The CLTV/CAC Ratio summarizes a plethora of information—including anticipated average lifetime revenue per customer, customer churn, and sales and marketing costs—into a single number that can be easily understood and used to evaluate the future prospects of your business.
#
# For example, a high CLTV/CAC Ratio means you have the potential to grow faster—and need less capital to do so. Companies with higher CLTV/CAC Ratios typically have higher valuations and an easier time securing funding from investors.
#
# A lower CLTV/CAC Ratio means your company is not as efficient at acquiring high value customers, and will likely need more capital to fuel revenue growth. The need for more capital and the slower growth rate means lower valuations from investors.
#
#
# How to calculate CLTV/CAC
#
# There are several ways to calculate CLTV. One way is with this formula:
#
# CLTV = Average Revenue per Account (ARPA) / Customer Churn
#
# Or you can calculate CLTV using this formula:
#
# CLTV = Average Revenue per Account (ARPA) × Average Customer Lifetime
# ```
#
# 4) What would be good metrics of success for a consumer product that relies heavily on engagement and interaction?
# ```
# Companies will usually have a Key Performance Indicator equation that builds points based on the value of new content, shares and likes.  From there, you can calculaute
# UserEngagementRate = sum of all users' engagement points / UniqueUser.
#
# This will show you how engaged an avg user is.
#
# Other useful KPIs would be:
# Revenue per Engagement Point = Revenue / sum of all users' engagement points- this would tell you up to what cost is it profitable for your business to stimulate interaction.
# ```
# 5) What would be good metrics of success for a consumer product that offer in-app purchases?
# ```
# Percent of total users that make in-app purchases
# Revenue/total users
# ```
# 6) A certain metric is violating your expectations by going down or up more than you expect. How would you try to identify the cause of the change?
#
#
# 7) Growth for total number of tweets sent has been slow this month. What data would you look at to determine the cause of the problem?
#
#
# 8) You're a restaurant andare approached by Groupon to run a deal. What data would you ask from them in order to determine whether or not to do the deal?
# ```
# I would want to know number of returning customers/groupon purchases.  I would also want to know the ROI, as well as increase in revenue/groupon purchases.
# ```
#
# 9) You are tasked with improving the efficiency of a subway system.  Where would you start?
#
#
# 10) Say you're working on Facebook News Feed. What would be some metrics that you think are important?  How would you make the news each person gets more relevant?
# ```
# ```
#
# 11) How would you measure the impact that sponsored stories on Facebook News Feed have on user engagement?
#
# 12) You are on a data science team at Uber and you are asked to start thinking about surge pricing. What would be the objectives of such a product and how would you start looking into this?
#
# 13) Say that you are Netflix.  How would you determine which original series you should invest in and create?
#
# 14) What kind of services would find churn helpful? How would you calculate churn?
#
# 15) Let's day that you're scheduling content for a content provider on television.  How would you dtermine the best times to schedule content?
